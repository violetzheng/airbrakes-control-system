# %%
mach_numbers = [0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8]
extensions = [0,0.005086,0.010172,0.15258,0.20344,0.02543]
coordinates = []

# %%
mach_data = []
extn_data = []
press_data = []
drag_data = []

# %%
import csv 
# 101 kpa 
with open('101_drag.csv') as file_obj: 
    reader_obj = csv.reader(file_obj)     
    row_ind = 0
    for row in reader_obj: 
        for col_ind in range(0,6):
            coordinates.append([float(mach_numbers[row_ind]),float(extensions[col_ind]),101.0,float(row[col_ind])])
            mach_data.append(float(mach_numbers[row_ind]))
            extn_data.append(float(extensions[col_ind]))
            press_data.append(101.0)
            drag_data.append(float(row[col_ind]))
        row_ind += 1

# %%
# 70 kpa 
with open('70_drag.csv') as file_obj: 
    reader_obj = csv.reader(file_obj) 

    row_ind = 0
    for row in reader_obj: 
        for col_ind in range(0,6):
            coordinates.append([float(mach_numbers[row_ind]),float(extensions[col_ind]),70.0,float(row[col_ind])])
            mach_data.append(float(mach_numbers[row_ind]))
            extn_data.append(float(extensions[col_ind]))
            press_data.append(70.0)
            drag_data.append(float(row[col_ind]))
        row_ind += 1

# %%
print(coordinates)
# Out:
# [[0.3, 0.0, 101.0, 29.2], [0.3, 0.005086, 101.0, 30.6038596], [0.3, 0.010172, 101.0, 34.8449676], [0.3, 0.15258, 101.0, 39.392762], [0.3, 0.20344, 101.0, 44.363468], [0.3, 0.02543, 101.0, 50.455588], [0.35, 0.0, 101.0, 39.3438984], [0.35, 0.005086, 101.0, 40.980028], [0.35, 0.010172, 101.0, 46.829176], [0.35, 0.15258, 101.0, 53.783896], [0.35, 0.20344, 101.0, 60.51684], [0.35, 0.02543, 101.0, 68.540368], [0.4, 0.0, 101.0, 50.592692], [0.4, 0.005086, 101.0, 52.728228], [0.4, 0.010172, 101.0, 60.47708], [0.4, 0.15258, 101.0, 68.513336], [0.4, 0.20344, 101.0, 78.251624], [0.4, 0.02543, 101.0, 88.5276], [0.45, 0.0, 101.0, 63.127608], [0.45, 0.005086, 101.0, 65.99966], [0.45, 0.010172, 101.0, 76.046776], [0.45, 0.15258, 101.0, 85.60814], [0.45, 0.20344, 101.0, 98.286556], [0.45, 0.02543, 101.0, 112.29546], [0.5, 0.0, 101.0, 77.004832], [0.5, 0.005086, 101.0, 80.78416], [0.5, 0.010172, 101.0, 93.2923], [0.5, 0.15258, 101.0, 105.561292], [0.5, 0.20344, 101.0, 120.300416], [0.5, 0.02543, 101.0, 137.001992], [0.55, 0.0, 101.0, 92.218236], [0.55, 0.005086, 101.0, 97.163872], [0.55, 0.010172, 101.0, 112.376896], [0.55, 0.15258, 101.0, 127.570044], [0.55, 0.20344, 101.0, 144.258336], [0.55, 0.02543, 101.0, 165.968488], [0.6, 0.0, 101.0, 108.923832], [0.6, 0.005086, 101.0, 115.061568], [0.6, 0.010172, 101.0, 134.061112], [0.6, 0.15258, 101.0, 154.232372], [0.6, 0.20344, 101.0, 173.907792], [0.6, 0.02543, 101.0, 198.87174], [0.65, 0.0, 101.0, 127.055288], [0.65, 0.005086, 101.0, 134.834648], [0.65, 0.010172, 101.0, 156.390792], [0.65, 0.15258, 101.0, 177.673132], [0.65, 0.20344, 101.0, 203.638128], [0.65, 0.02543, 101.0, 230.748264], [0.7, 0.0, 101.0, 146.665884], [0.7, 0.005086, 101.0, 156.592948], [0.7, 0.010172, 101.0, 181.584888], [0.7, 0.15258, 101.0, 206.38128], [0.7, 0.20344, 101.0, 237.189536], [0.7, 0.02543, 101.0, 265.524612], [0.75, 0.0, 101.0, 167.820228], [0.75, 0.005086, 101.0, 179.747572], [0.75, 0.010172, 101.0, 208.852396], [0.75, 0.15258, 101.0, 237.68494], [0.75, 0.20344, 101.0, 274.675336], [0.75, 0.02543, 101.0, 309.803308], [0.8, 0.0, 101.0, 190.731816], [0.8, 0.005086, 101.0, 205.076228], [0.8, 0.010172, 101.0, 238.66408], [0.8, 0.15258, 101.0, 271.98926], [0.8, 0.20344, 101.0, 314.372956], [0.8, 0.02543, 101.0, 357.325], [0.3, 0.0, 70.0, 21.3504128], [0.3, 0.005086, 70.0, 22.0595048], [0.3, 0.010172, 70.0, 24.9088716], [0.3, 0.15258, 70.0, 27.9864184], [0.3, 0.20344, 70.0, 31.1026324], [0.3, 0.02543, 70.0, 34.4154968], [0.35, 0.0, 70.0, 28.4764288], [0.35, 0.005086, 70.0, 29.4968188], [0.35, 0.010172, 70.0, 33.442484], [0.35, 0.15258, 70.0, 37.7072924], [0.35, 0.20344, 70.0, 42.431004], [0.35, 0.02543, 70.0, 49.268968], [0.4, 0.0, 70.0, 36.5797444], [0.4, 0.005086, 70.0, 37.9425576], [0.4, 0.010172, 70.0, 43.181036], [0.4, 0.15258, 70.0, 48.228044], [0.4, 0.20344, 70.0, 54.337208], [0.4, 0.02543, 70.0, 63.177396], [0.45, 0.0, 70.0, 45.626064], [0.45, 0.005086, 70.0, 47.465936], [0.45, 0.010172, 70.0, 54.248124], [0.45, 0.15258, 70.0, 61.153508], [0.45, 0.20344, 70.0, 68.123176], [0.45, 0.02543, 70.0, 78.544968], [0.5, 0.0, 70.0, 55.608328], [0.5, 0.005086, 70.0, 58.031028], [0.5, 0.010172, 70.0, 66.47724], [0.5, 0.15258, 70.0, 75.0606], [0.5, 0.20344, 70.0, 83.772648], [0.5, 0.02543, 70.0, 99.321344], [0.55, 0.0, 70.0, 66.491156], [0.55, 0.005086, 70.0, 69.620664], [0.55, 0.010172, 70.0, 79.97704], [0.55, 0.15258, 70.0, 90.395844], [0.55, 0.20344, 70.0, 101.067112], [0.55, 0.02543, 70.0, 118.531744], [0.6, 0.0, 70.0, 78.3694], [0.6, 0.005086, 70.0, 82.318212], [0.6, 0.010172, 70.0, 94.992516], [0.6, 0.15258, 70.0, 107.6595], [0.6, 0.20344, 70.0, 121.253364], [0.6, 0.02543, 70.0, 138.66022], [0.65, 0.0, 70.0, 91.236292], [0.65, 0.005086, 70.0, 96.208516], [0.65, 0.010172, 70.0, 110.87602], [0.65, 0.15258, 70.0, 125.462168], [0.65, 0.20344, 70.0, 140.80704], [0.65, 0.02543, 70.0, 161.66664], [0.7, 0.0, 70.0, 105.077064], [0.7, 0.005086, 70.0, 111.278992], [0.7, 0.010172, 70.0, 128.460616], [0.7, 0.15258, 70.0, 145.4790 ...

# %%
import numpy as np
from scipy.optimize import minimize

# %%
mach_data = np.array(mach_data)
extn_data = np.array(extn_data)
press_data = np.array(press_data)
drag_data = np.array(drag_data)

# %%
def func(coef, x, y, z, m):
    a = coef[0]
    b = coef[1]
    c = coef[2]
    return np.linalg.norm(m - a*x**2 + b*y**2 + c*z**2)

# %%
res = minimize(func, [1, 1, 1], args=(mach_data, extn_data, press_data, drag_data))
print(res)
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 380.74849385862836
#         x: [ 2.948e+02 -4.155e+02 -2.394e-03]
#       nit: 23
#       jac: [ 3.815e-06  0.000e+00 -3.464e-03]
#  hess_inv: [[ 8.621e+01  3.028e+01  3.058e-03]
#             [ 3.028e+01  3.330e+03 -2.916e-03]
#             [ 3.058e-03 -2.916e-03  1.559e-07]]
#      nfev: 263
#      njev: 63

# %%
a, b, c = res.x
